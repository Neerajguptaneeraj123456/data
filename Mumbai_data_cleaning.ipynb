# %% [markdown]
# <a href="https://colab.research.google.com/github/Neerajguptaneeraj123456/data/blob/main/Mumbai_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/content/Mumbai House Prices.csv")

# %%
df1.head()
# Out:
#    bhk       type                              locality  area  price  \
# 0    3  Apartment   Lak And Hanware The Residency Tower   685   2.50
# 1    2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2    2  Apartment                         Romell Serene   610   1.73
# 3    2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4    2  Apartment                         Origin Oriana   659  94.11
#
#   price_unit          region              status  age
# 0         Cr    Andheri West       Ready to move  New
# 1          L    Naigaon East  Under Construction  New
# 2         Cr   Borivali West  Under Construction  New
# 3          L          Panvel  Under Construction  New
# 4          L  Mira Road East  Under Construction  New

# %%
df1.head()
df1["price_unit"].value_counts()
# Out:
# price_unit
# Cr    40981
# L     35057
# Name: count, dtype: int64

# %%
df1['price_unit'].unique()

# new_cr = df1[df1['price_unit'] == 'Cr'].shape

# new_L = df1[df1['price_unit'] == 'L'].shape
# # new_L


df1['price']
# df1.iloc[76033]
# Out:
# 0         2.5000
# 1         0.5251
# 2         1.7300
# 3         0.5998
# 4         0.9411
#           ...
# 76033     7.0000
# 76034    12.0000
# 76035    10.0000
# 76036     4.2500
# 76037    25.0000
# Name: price, Length: 76038, dtype: float64

# %%
for i in range(df1.shape[0]):
    if df1.loc[i, 'price_unit'] == 'L':
        # print("hello")
        # df1.loc[i, 'price'] = df1.loc[i, 'price'] / 100
# Out:
# Streaming output truncated to the last 5000 lines.
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
for i in range(0 , df1.shape[0]):
  if df1['price_unit'][i] == 'L':
    # print("hello")

    df1['price'][i] = df1['price'][i]/100

# df[]
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1['price'][i] = df1['price'][i]/100
# /tmp/ipython-input-2619869427.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price'][i] = df1['price'][i]/100
# /tmp/ipython-input-2619869427.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...

# %%
df1['price_unit'] == 'L'
df1[ 'price_unit'][1] == 'L'
# Out:
# True

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bhk         76038 non-null  int64
#  1   type        76038 non-null  object
#  2   locality    76038 non-null  object
#  3   area        76038 non-null  int64
#  4   price       76038 non-null  float64
#  5   price_unit  76038 non-null  object
#  6   region      76038 non-null  object
#  7   status      76038 non-null  object
#  8   age         76038 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 5.2+ MB

# %%
df1['price']
# Out:
# 0         2.5000
# 1         0.5251
# 2         1.7300
# 3         0.5998
# 4         0.9411
#           ...
# 76033     7.0000
# 76034    12.0000
# 76035    10.0000
# 76036     4.2500
# 76037    25.0000
# Name: price, Length: 76038, dtype: float64

# %%
df2 = pd.read_csv("/content/mumbai.csv")
df2.shape
# Out:
# (9514, 55)

# %%
df1["type"].value_counts()
# df1["status"].value_counts()
# Out:
# type
# Apartment            74854
# Studio Apartment       882
# Villa                  226
# Independent House       73
# Penthouse                3
# Name: count, dtype: int64

# %% [markdown]
# # ** details of df1 **

# %% [markdown]
# *   PREFERENCE -> use -> analysis

# %%
# df2.drop(columns=['AGE','POSTING_DATE','UPDATE_DATE' , "RES_COM" , 'PROPERTY_NUMBER' ,  'PROJ_ID', 'BUILDING_ID', 'VERIFIED', 'FEATURES' ,'PRODUCT_TYPE', 'EXPIRY_DATE' , 'PROPERTY_TYPE__U', 'VALUE_LABEL' ,'CLASS_HEADING' , 'CLASS_LABEL', 'REGISTER_DATE__U','TOTAL_LANDMARK_COUNT',
# "SOCIETY_NAME" , "BUILDING_NAME" ,"FLOOR_NUM" ], inplace=True
# )
# df2.columns
# df2.head(3)

df2.shape
# Out:
# (9514, 55)

# %%
df2.columns
# df2['FEATURES']
# Out:
# Index(['SPID', 'PROP_ID', 'PREFERENCE', 'DESCRIPTION', 'PROPERTY_TYPE', 'CITY',
#        'TRANSACT_TYPE', 'OWNTYPE', 'BEDROOM_NUM', 'PRICE_PER_UNIT_AREA',
#        'FURNISH', 'FACING', 'AGE', 'TOTAL_FLOOR', 'FEATURES', 'REGISTER_DATE',
#        'POSTING_DATE', 'UPDATE_DATE', 'CLASS', 'RES_COM', 'PROP_NAME',
#        'PROPERTY_NUMBER', 'MIN_PRICE', 'MAX_PRICE', 'PRICE_SQFT', 'PROJ_ID',
#        'BUILDING_ID', 'VERIFIED', 'MAP_DETAILS', 'MIN_AREA_SQFT',
#        'MAX_AREA_SQFT', 'AMENITIES', 'ALT_TAG', 'PRODUCT_TYPE', 'TOP_USPS',
#        'EXPIRY_DATE', 'PROPERTY_TYPE__U', 'AREA', 'SECONDARY_AREA', 'PRICE',
#        'PROP_HEADING', 'VALUE_LABEL', 'CLASS_HEADING', 'CLASS_LABEL',
#        'REGISTER_DATE__U', 'REGISTERED_DAYS', 'PRIMARY_TAGS', 'SECONDARY_TAGS',
#        'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS', 'SOCIETY_NAME',
#        'BUILDING_NAME', 'location', 'BALCONY_NUM', 'FLOOR_NUM'],
#       dtype='object')

# %%
# df2.iloc[:/,10:15]
# df2.drop(columns=['SPID' , 'PROP_ID' , 'DESCRIPTION' ,'TRANSACT_TYPE','OWNTYPE'  , ] , axis=1, inplace=True)

# %%
df2['FORMATTED_LANDMARK_DETAILS'].value_counts()
# df2.shape
# Out:
# FORMATTED_LANDMARK_DETAILS
# [{'text': '1 Railway Station'}, {'text': '1 Metro Station'}, {'text': '1 Shopping'}, {'text': '1 Connectivity'}, {'text': '2 Educations'}, {'text': '1 Hospital'}, {'text': '1 Airport'}]                                                          191
# [{'text': '1 Railway Station'}, {'text': '1 Metro Station'}, {'text': '1 Shopping'}, {'text': '2 Connectivities'}, {'text': '2 Educations'}, {'text': '1 Hospital'}, {'text': '1 Airport'}, {'text': '1 Office Complex'}, {'text': '1 Hotels'}]    117
# [{'text': '1 Shopping'}, {'text': '3 Religious Places'}, {'text': '6 ATMs'}, {'text': '12 Hospitals'}, {'text': '1 Pharmacy'}]                                                                                                                      91
# ...

# %%
df1.head()
# Out:
#    bhk       type                              locality  area   price  \
# 0    3  Apartment   Lak And Hanware The Residency Tower   685  2.5000
# 1    2  Apartment     Radheya Sai Enclave Building No 2   640  0.5251
# 2    2  Apartment                         Romell Serene   610  1.7300
# 3    2  Apartment  Soundlines Codename Urban Rainforest   876  0.5998
# 4    2  Apartment                         Origin Oriana   659  0.9411
#
#   price_unit          region              status  age
# 0         Cr    Andheri West       Ready to move  New
# 1          L    Naigaon East  Under Construction  New
# 2         Cr   Borivali West  Under Construction  New
# 3          L          Panvel  Under Construction  New
# 4          L  Mira Road East  Under Construction  New

# %%
# df1.info()
df1['status'].value_counts()
# Out:
# status
# Ready to move         44982
# Under Construction    31056
# Name: count, dtype: int64

# %%
df1.head()
df1.drop(columns=['price_unit'], inplace=True)
df1.shape
# Out:
# (76038, 8)
