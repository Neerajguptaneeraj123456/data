# %% [markdown]
# <a href="https://colab.research.google.com/github/Neerajguptaneeraj123456/data/blob/main/sale_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/mumbai.csv')
# df.isnull()
df.iloc[:,50:]
# df['FORMATTED_LANDMARK_DETAILS'].value_counts()
df.shape
# Out:
# (9514, 55)

# %%
useColumns = ['PROPERTY_TYPE', 'CITY' , 'BEDROOM_NUM' ,'FURNISH','AGE' ,'FEATURES' , 'CLASS' ,'location', 'BALCONY_NUM' , 'AREA' , 'MIN_PRICE', 'MAX_PRICE', 'FORMATTED_LANDMARK_DETAILS' , 'PRICE'  ]

# %%
df['location'].value_counts()
# Out:
# location
# {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDING_ID': '289759', 'BUILDING_NAME': 'Lodha Amara', 'SOCIETY_NAME': 'Lodha Amara', 'LOCALITY_ID': '1124', 'LOCALITY_NAME': 'Kolshet Road', 'ADDRESS': None}                                                                    59
# {'CITY': '14', 'CITY_NAME': 'Central Mumbai suburbs', 'BUILDING_ID': '493609', 'BUILDING_NAME': 'Piramal Revanta', 'SOCIETY_NAME': 'Piramal Revanta', 'LOCALITY_ID': '4881', 'LOCALITY_NAME': 'Mulund West', 'ADDRESS': None}                                             40
# {'CITY': '219', 'CITY_NAME': 'Thane', 'BUILDING_ID': '373294', 'BUILDING_NAME': 'Piramal Vaikunth', 'SOCIETY_NAME': 'Piramal Vaikunth', 'LOCALITY_ID': '7934', 'LOCALITY_NAME': 'Balkum', 'ADDRESS': None}                                                                38
# ...

# %%
df = df[useColumns]
df.head()
df.shape
df.to_csv('step1_real_estate.csv', index=False)

# %%
df = pd.read_csv('/content/step1_real_estate.csv')

# %%
df.shape
# Out:
# (9514, 14)

# %%
df = pd.read_csv('/content/Mumbai House Prices.csv')
df.isnull().sum()
# df.info()

df.head(5)
# df['age'].value_counts()
df['type'] = df['type'].str.strip().str.lower()
df['locality'] = df['locality'].str.strip().str.title()

df.head()
def convert_price(price, unit):
    if unit == 'Cr':
        return price * 100
    elif unit == 'L':
        return price
    else:
        return None

df['price_lac'] = df.apply(lambda x: convert_price(x['price'], x['price_unit']), axis=1)
df.head()
# Out:
#    bhk       type                              locality  area  price  \
# 0    3  apartment   Lak And Hanware The Residency Tower   685   2.50
# 1    2  apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2    2  apartment                         Romell Serene   610   1.73
# 3    2  apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4    2  apartment                         Origin Oriana   659  94.11
#
#   price_unit          region              status  age  price_lac
# 0         Cr    Andheri West       Ready to move  New     250.00
# 1          L    Naigaon East  Under Construction  New      52.51
# 2         Cr   Borivali West  Under Construction  New     173.00
# 3          L          Panvel  Under Construction  New      59.98
# 4          L  Mira Road East  Under Construction  New      94.11

# %%
# df['region'] = df['region'].str.strip().str.title()
# df['status'] = df['status'].str.strip().str.lower()
# # df['price_unit'].value_counts()
# df.info()
df.drop(columns=['age'] , inplace=True)
df['locality'] = df['locality'].str.strip().str.lower()

# %%
df['region'] = df['region'].str.strip().str.lower()
df['status'] = df['status'].str.strip().str.lower()
df.columns
# Out:
# Index(['bhk', 'type', 'locality', 'area', 'price', 'region', 'status',
#        'price_lac'],
#       dtype='object')

# %%
# df['age'] = df['age'].replace('Unknown', np.nan)
# df.head()
# df['age'].value_counts()
# df['age']
df
# df.duplicated()
df.columns
df['type'].duplicated().sum()
df['type'].value_counts()
df[df.duplicated()].
# Out:
#        bhk       type                                  locality  area  price  \
# 49       3  apartment       lak and hanware the residency tower   685   2.50
# 50       2  apartment         radheya sai enclave building no 2   640  52.51
# 51       2  apartment                             romell serene   610   1.73
# 52       2  apartment      soundlines codename urban rainforest   876  59.98
# 53       2  apartment                             origin oriana   659  94.11
# ...    ...        ...                                       ...   ...    ...
# 76023    2  apartment  narang realty and wadhwa group courtyard   706   1.66
# 76024    3  apartment  narang realty and wadhwa group courtyard  1091   2.80
# 76027    3  apartment                         dosti west county  1115   1.52
# 76028    2  apartment                         dosti west county   639  87.47
# 76029    2  apartment                         dosti west county   550  75.26
#
# ...

# %%
df.head()
# df.shape
# df['TRANSACT_TYPE'].value_counts()
df['CITY'].value_counts()
# df['CITY'].apply(lambda df['c'])





# for i in range(0 ,df.shape[0] ):
#   if df['CITY'][i]== 'Mumbai Andheri-Dahisar':
#     df['CITY'][i]== 'Western Mumbai suburb':

#   if  df['CITY'][i]== 'Mumbai Beyond Thane':
#     df['CITY'][i]== 'Thane':
#   if  df['CITY'][i]== 'Mira Road And Beyond':
#     df['CITY'][i]== 'Northern Mumbai suburb':
# Out:
# CITY
# Navi Mumbai               1178
# Central Mumbai suburbs     911
# Thane                      634
# Mumbai Andheri-Dahisar     429
# South Mumbai               374
# Mumbai Beyond Thane        265
# Mira Road And Beyond       247
# Mumbai Harbour             195
# Mumbai South West           68
# Name: count, dtype: int64

# %%
df['CITY'] = df['CITY'].replace({
    'Mumbai Andheri-Dahisar': 'Western Mumbai Suburb',
    'Mumbai Beyond Thane': 'Thane',
    'Mira Road And Beyond': 'Northern Mumbai Suburb'

} )

# %%
df['CITY'].value_counts()
df['PRICE'] = df['PRICE'].fillna(method='ffill')

# df
# Out:
# /tmp/ipython-input-1181200572.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['PRICE'] = df['PRICE'].fillna(method='ffill')

# %%
# df.drop(columns=['BALCONY_NUM'] , inplace=True)
df.head(10)
# df['AGE'].value_counts()
# df['FEATURES'].value_counts()

# df['CLASS'].value_counts()
# df['MIN_PRICE'].value_counts().   ------ null
# df['MAX_PRICE'].value_counts()      ------>null


# df['AMENITIES'].value_counts()
# df['BEDROOM_NUM'].isnull().sum()
# df['BEDROOM_NUM'].fillna()
# Out:
#            PROPERTY_TYPE                    CITY  TRANSACT_TYPE  BEDROOM_NUM  \
# 0  Residential Apartment  Central Mumbai suburbs            2.0          3.0
# 1  Residential Apartment   Western Mumbai Suburb            2.0          3.0
# 2  Residential Apartment   Western Mumbai Suburb            2.0          4.0
# 3  Residential Apartment   Western Mumbai Suburb            2.0          3.0
# 4  Residential Apartment  Central Mumbai suburbs            2.0          2.0
# 5  Residential Apartment  Central Mumbai suburbs            2.0          1.0
# 6  Residential Apartment             Navi Mumbai            2.0          2.0
# 7  Residential Apartment       Mumbai South West            2.0          2.0
# 8  Residential Apartment            South Mumbai            2.0          3.0
# 9  Residential Apartment            South Mumbai            2.0          2.0
#
#    FURNISH  AGE FEATURES CLASS  MIN_PRICE  MAX_PRICE  AMENITIES  TOP_USPS  \
# ...

# %%
# df.isnull()

# %%
df.drop(columns=['MAX_PRICE'] , inplace = True)
df.isnull().sum()
df['CITY'].unique()
df['PRICE'].value_counts()
df[df['PRICE']=='Price on Request']
df = df[df['PRICE'] != 'Price on Request']
df['location'].value_counts()
df['BALCONY_NUM']


df.head()
# Out:
#            PROPERTY_TYPE                    CITY  TRANSACT_TYPE  BEDROOM_NUM  \
# 0  Residential Apartment  Central Mumbai suburbs            2.0          3.0
# 1  Residential Apartment   Western Mumbai Suburb            2.0          3.0
# 3  Residential Apartment   Western Mumbai Suburb            2.0          3.0
# 4  Residential Apartment  Central Mumbai suburbs            2.0          2.0
# 5  Residential Apartment  Central Mumbai suburbs            2.0          1.0
#
#    FURNISH  AGE FEATURES CLASS  MIN_PRICE  AMENITIES  TOP_USPS  \
# 0        0    5        N     B   26800000        NaN       NaN
# 1        0    5        N     B          0        NaN       NaN
# 3        0    5        N     B   56100000        NaN       NaN
# 4        0    5        N     B    9099000        NaN       NaN
# 5        0    5        N     B    4799000        NaN       NaN
#
#            EXPIRY_DATE               AREA       SECONDARY_AREA  \
# ...

# %%
# df['AREA']
df['AREA_f'] = df['AREA'].str.replace('sq.ft.', '', regex=False)
df["PRICE"]
df.head()
# Out:
#            PROPERTY_TYPE                    CITY  TRANSACT_TYPE  BEDROOM_NUM  \
# 0  Residential Apartment  Central Mumbai suburbs            2.0          3.0
# 1  Residential Apartment  Mumbai Andheri-Dahisar            2.0          3.0
# 2  Residential Apartment  Mumbai Andheri-Dahisar            2.0          4.0
# 3  Residential Apartment  Mumbai Andheri-Dahisar            2.0          3.0
# 4  Residential Apartment  Central Mumbai suburbs            2.0          2.0
#
#    FURNISH  AGE FEATURES CLASS  MIN_PRICE  MAX_PRICE  AMENITIES  TOP_USPS  \
# 0        0    5        N     B   26800000   31700000        NaN       NaN
# 1        0    5        N     B          0   35000000        NaN       NaN
# 2        0    5        N     B          0          0        NaN       NaN
# 3        0    5        N     B   56100000   56100000        NaN       NaN
# 4        0    5        N     B    9099000    9099000        NaN       NaN
#
# ...

# %%
def area_to_numeric(area):
    if '-' in area:
        # If it’s a range, take average of lower and upper bound
        low, high = area.split('-')
        return high
    else:
      return area



df['AREA_f'] = df['AREA_f'].apply(area_to_numeric)
df.isnull().sum()
# df.shape
# df
# Out:
# PROPERTY_TYPE        0
# CITY                 0
# TRANSACT_TYPE        0
# BEDROOM_NUM          9
# FURNISH              0
# AGE                  0
# FEATURES             0
# CLASS                0
# MIN_PRICE            0
# MAX_PRICE            0
# AMENITIES         4301
# TOP_USPS          4301
# EXPIRY_DATE          0
# AREA                 0
# SECONDARY_AREA       0
# PRICE                0
# location             0
# BALCONY_NUM       4301
# AREA_f               0
# dtype: int64

# %%
for i in range(0,4301):
  if df['PRICE'][i]== None:
    df['PRICE'][i] = ((df['MIN_PRICE'][i]+df['MAX_PRICE'][i]) / 2)/100000
# Out:
# /tmp/ipython-input-2741106186.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['PRICE'][i] = ((df['MIN_PRICE'][i]+df['MAX_PRICE'][i]) / 2)/100000
# /tmp/ipython-input-2741106186.py:3: SettingWithCopyWarning:
# ...

# %%
df['MIN_PRICE'][1]+df['MAX_PRICE'][1] / 2
# Out:
# np.float64(17500000.0)

# %%
df.isnull().sum()
# Out:
# PROPERTY_TYPE        0
# CITY                 0
# TRANSACT_TYPE        0
# BEDROOM_NUM          9
# FURNISH              0
# AGE                  0
# FEATURES             0
# CLASS                0
# MIN_PRICE            0
# MAX_PRICE            0
# AMENITIES         4301
# TOP_USPS          4301
# EXPIRY_DATE          0
# AREA                 0
# SECONDARY_AREA       0
# PRICE                0
# location             0
# BALCONY_NUM       4301
# dtype: int64

# %%
df.head()
# df['AREA']
# df['SECONDARY_AREA']
df['PRICE'].isnull()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 4296     True
# 4297     True
# 4298     True
# 4299     True
# 4300     True
# Name: PRICE, Length: 4301, dtype: bool

# %%
# df.drop(columns=["MIN_PRICE",	"AMENITIES"	,"TOP_USPS","EXPIRY_DATE"] , inplace=True)

# df.drop(columns=["FEATURES",'TRANSACT_TYPE', ] , inplace=True)
# df.drop(columns=["BALCONY_NUM", ] , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-269152181.py in <cell line: 0>()
# ----> 1 df.drop(columns=["MIN_PRICE",   "AMENITIES"     ,"TOP_USPS","EXPIRY_DATE"] , inplace=True)
#       2
#       3 df.drop(columns=["FEATURES",'TRANSACT_TYPE', ] , inplace=True)
#       4 df.drop(columns=["BALCONY_NUM", ] , inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
df

cl = ['BALCONY_NUM','AREA', 'EXPIRY_DATE' , 'TOP_USPS' ,'AMENITIES', 'MAX_PRICE', 'MIN_PRICE' ,'FURNISH', 'TRANSACT_TYPE'  ]
# df['FEATURES'].value_counts()
# df.drop(columns=['FEATURES'], inplace=True)
df['CITY'].value_counts()
df.isnull().sum()
# df['BEDROOM_NUM'].fillna()
# df['BEDROOM_NUM'].fillna(method='ffill', inplace=True)
df.shape
# Out:
# (4301, 9)

# %%
df.to_csv('house_csv.csv',index=False)
